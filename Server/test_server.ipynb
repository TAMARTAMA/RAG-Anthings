# %%
import requests

url = "http://127.0.0.1:8002/ask"
data = {
    "session": "test_session",
    "message": "שלום, איך היום?"
}

response = requests.post(url, json=data)
print(response.json())
# Out:
# {'answer': 'echo: שלום, איך היום?', 'probability': 67}

# %%
data = {
    "session": "test_session",
    "message": "מה מזג האויר?"
}

response = requests.post(url, json=data)
print(response.json())
# Out:
# {'answer': 'echo: מה מזג האויר?', 'probability': 59}

# %%
data = {
    "session": "test_session3",
    "message": "What is the capital of France?"
}

response = requests.post(url, json=data)
print(response.json())
# Out:
# {'answer': 'echo: What is the capital of France?', 'probability': 38}

# %%
url = "http://127.0.0.1:8002/rate"
data = {
    "id_question": 1,  # מזהה השאלה שברצונך לדרג
    "rating": 0        # 1 = לייק, 0 = דיסלייק
}

resp = requests.post(url, json=data)
print(resp.json())
# Out:
# {'status': 'ok', 'id_question': 1, 'rating': 0}

# %%
url = "http://127.0.0.1:8002/rate"
data = {
    "id_question": 2,  # מזהה השאלה שברצונך לדרג
    "rating": 0        # 1 = לייק, 0 = דיסלייק
}

resp = requests.post(url, json=data)
print(resp.json())
# Out:
# {'status': 'ok', 'id_question': 2, 'rating': 0}
